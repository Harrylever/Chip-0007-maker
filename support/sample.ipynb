# %%
import pandas as pd
df = pd.read_csv('csvfiles/7Xo1lV6o6vP5H062.csv')

# %%
df.head()
# Out:
#    Serial Number              Filename  \
# 0             21        abdul-the-vibe
# 1             22      emeka-the -clown
# 2             23      salam-the-odogwu
# 3             24  charles-the-exporter
# 4             25         wole-the-pimp
#
#                                          Description Gender  Attributes  \
# 0  abdul the life of the party and can never be c...   male         NaN
# 1     emeka the funny man, always making silly jokes   male         NaN
# 2  salam is a big time textile marketer always so...   male         NaN
# 3  charles a business man an importer and exporte...   male         NaN
# 4  wole knows all the babes in town and is always...   male         NaN
#
#                                    UUID  HASH
# 0  770f817a-9d9a-4772-9a91-e66dd9d03470   NaN
# 1  78810fa6-a7ef-4d83-bf57-caf49db4ee69   NaN
# 2  f2957ded-022c-4b07-92c6-b345d4816a67   NaN
# 3  09395e76-19ed-4852-8748-795ee7496a8e   NaN
# 4  4d94d4f7-9b69-4e43-9db1-1fe83df92857   NaN

# %%
df_2 = df.reset_index(drop=True)

# %%
df_2
# Out:
#     Serial Number                    Filename  \
# 0              21              abdul-the-vibe
# 1              22            emeka-the -clown
# 2              23            salam-the-odogwu
# 3              24        charles-the-exporter
# 4              25               wole-the-pimp
# 5              26             saro-the-baller
# 6              27              ade-omo-yoruba
# 7              28              shola-cool-kid
# 8              29          charlie-the-smoker
# 9              30             femi-the-badguy
# 10             31                 sinzu-money
# 11             32  obinna-the-palmwine tapper
# 12             33               aminu-maikudi
# 13             34      sabinus-the-town crier
# 14             35                adisa-ibadan
# 15             36         linda-the-navigator
# 16             37          kemi-the-iron lady
# 17             38        mercy-the-sassy lady
# 18             39                sandra-money
# ...
